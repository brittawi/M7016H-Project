# %%
from descriptive_statistics import DiabetesDataBase

# %%
csv_path = "diabetes.csv"
ddb = DiabetesDataBase(csv_path)

# %%
# analyse and describe Data before the split
ddb.describe_data(ddb.diabetes_df)
ddb.plot_histogram_summary(ddb.diabetes_df)
ddb.plot_boxplot_summary(ddb.diabetes_df)
#ddb.plot_histogram_individual()
#ddb.plot_boxplot_individual()
# TODO plots
ddb.plot_connection_to_outcome("Age")
ddb.plot_connection_to_outcome("BloodPressure")
# ddb.plot_connection_to_outcome("Glucose")
# ddb.plot_connection_to_outcome("Insulin")
# ddb.plot_connection_to_outcome("BMI")
ddb.show_label_balance(ddb.diabetes_df)
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin
# count   768.000000  768.000000     768.000000     768.000000  768.000000  \
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# min      0.000000                  0.078000   21.000000    0.000000
# 25%     27.300000                  0.243750   24.000000    0.000000
# 50%     32.000000                  0.372500   29.000000    0.000000
# 75%     36.600000                  0.626250   41.000000    1.000000
# max     67.100000                  2.420000   81.000000    1.000000
# Null values: False
# Number of zeros for the column Insulin: 374

# %%
# analyse and describe data after the split for train
ddb.describe_data(ddb.train_set)
ddb.plot_histogram_summary(ddb.train_set)
ddb.plot_boxplot_summary(ddb.train_set)
ddb.show_label_balance(ddb.train_set)
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin
# count   292.000000  292.000000     292.000000     292.000000  292.000000  \
# mean      3.195205  119.678082      70.664384      29.075342  133.126712
# std       3.291076   28.588546      11.957414      10.637795   74.667011
# min       0.000000   56.000000      24.000000       7.000000   14.000000
# 25%       1.000000   99.000000      64.000000      21.000000   75.000000
# 50%       2.000000  117.000000      70.000000      29.000000  120.000000
# 75%       5.000000  139.000000      78.000000      36.250000  176.500000
# max      17.000000  198.000000     102.000000      63.000000  360.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  292.000000                292.000000  292.000000  292.000000
# mean    32.957192                  0.521435   30.650685    0.304795
# std      6.737420                  0.326701   10.230735    0.461111
# min     19.300000                  0.088000   21.000000    0.000000
# 25%     27.875000                  0.277750   23.000000    0.000000
# 50%     33.200000                  0.445000   27.000000    0.000000
# 75%     36.950000                  0.692000   35.000000    1.000000
# max     59.400000                  2.420000   81.000000    1.000000
# Null values: False
# Number of zeros for the column Insulin: 0

# %%
# split the data
X_train, X_val, X_test, y_train, y_val, y_test = ddb.get_splits()
print(len(X_train))
print(len(X_val))
print(len(X_test))
# Out:
# 292
# 36
# 38
