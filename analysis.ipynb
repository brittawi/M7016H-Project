# %%
from descriptive_statistics import DiabetesDataBase

# %%
csv_path = "diabetes.csv"
ddb = DiabetesDataBase(csv_path)
# Out:
# c:\awilde\britta\LTU\AppliedAIHealthCare\Project\M7016H-Project\descriptive_statistics.py:37: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_val[no_zero_list] = train_val[no_zero_list].replace(0, np.NaN) # convert zeros to NaN as this is easier to work with

# %%
# analyse and describe Data before the split
ddb.describe_data(ddb.diabetes_df)
ddb.plot_histogram_summary(ddb.diabetes_df)
ddb.plot_boxplot_summary(ddb.diabetes_df)
#ddb.plot_histogram_individual()
#ddb.plot_boxplot_individual()
# TODO plots
ddb.plot_connection_to_outcome("Age")
ddb.plot_connection_to_outcome("BloodPressure")
# ddb.plot_connection_to_outcome("Glucose")
# ddb.plot_connection_to_outcome("Insulin")
# ddb.plot_connection_to_outcome("BMI")
ddb.show_label_balance(ddb.diabetes_df)
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin
# count   768.000000  768.000000     768.000000     768.000000  768.000000  \
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# min      0.000000                  0.078000   21.000000    0.000000
# 25%     27.300000                  0.243750   24.000000    0.000000
# 50%     32.000000                  0.372500   29.000000    0.000000
# 75%     36.600000                  0.626250   41.000000    1.000000
# max     67.100000                  2.420000   81.000000    1.000000
# Null values: False
# Number of zeros for the column Insulin: 374

# %%
# analyse and describe data after the split for train_val
ddb.describe_data(ddb.train_val_set)
ddb.plot_histogram_summary(ddb.train_val_set)
ddb.plot_boxplot_summary(ddb.train_val_set)
ddb.show_label_balance(ddb.train_val_set)
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin
# count   691.000000  691.000000     691.000000     691.000000  691.000000  \
# mean      3.839363  121.575802      72.319149      29.176715  156.723164
# std       3.372774   30.659504      12.036477       8.767693   84.084437
# min       0.000000   44.000000      24.000000       7.000000   14.000000
# 25%       1.000000   99.000000      64.000000      25.000000  122.000000
# 50%       3.000000  117.000000      72.000000      29.176715  156.723164
# 75%       6.000000  141.000000      80.000000      32.000000  156.723164
# max      17.000000  197.000000     114.000000      99.000000  744.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  691.000000                691.000000  691.000000  691.000000
# mean    32.417500                  0.469035   33.247467    0.348770
# std      6.880953                  0.329596   11.741212    0.476926
# min     18.200000                  0.078000   21.000000    0.000000
# 25%     27.550000                  0.238000   24.000000    0.000000
# 50%     32.400000                  0.370000   29.000000    0.000000
# 75%     36.500000                  0.630000   41.000000    1.000000
# max     67.100000                  2.420000   72.000000    1.000000
# Null values: False
# Number of zeros for the column Insulin: 0

# %%
# analyse and describe data after the split for test
ddb.describe_data(ddb.test_set)
ddb.plot_histogram_summary(ddb.test_set)
ddb.plot_boxplot_summary(ddb.test_set)
ddb.show_label_balance(ddb.test_set)
# Out:
#        Pregnancies    Glucose  BloodPressure  SkinThickness     Insulin
# count    40.000000   40.00000      40.000000      40.000000   40.000000  \
# mean      3.550000  121.77500      69.650000      28.625000  145.150000
# std       3.226096   30.29131      11.092964      11.265303  130.195228
# min       0.000000   71.00000      50.000000      10.000000   18.000000
# 25%       1.000000  100.00000      64.000000      22.000000   76.750000
# 50%       2.000000  122.00000      70.000000      28.500000  119.000000
# 75%       5.250000  138.25000      78.500000      35.000000  177.000000
# max      11.000000  198.00000      90.000000      51.000000  846.000000
#
#              BMI  DiabetesPedigreeFunction        Age    Outcome
# count  40.000000                  40.00000  40.000000  40.000000
# mean   32.717500                   0.51550  31.725000   0.350000
# std     5.647141                   0.28563  12.528915   0.483046
# min    22.300000                   0.16100  21.000000   0.000000
# 25%    28.675000                   0.32725  24.000000   0.000000
# 50%    33.100000                   0.43250  26.500000   0.000000
# 75%    37.300000                   0.62875  36.250000   1.000000
# max    49.700000                   1.39100  81.000000   1.000000
# Null values: False
# Number of zeros for the column Insulin: 0

# %%
# split the data
X_train, X_val, X_test, y_train, y_val, y_test = ddb.splitData()
print(len(X_train))
print(len(X_val))
print(len(X_test))
# Out:
# 604
# 87
# 40
